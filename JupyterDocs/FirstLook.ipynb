# %% [markdown]
# # First Look at the Data

# %% [markdown]
# ### 1. Set up

# %% [markdown]
# The cell below will import all the packages required in the downstream analyses as well as set all the necessary variables and data paths.

# %%
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt
import numpy as np

import qiime2 as q2

# %matplotlib inline

# location of this week's data and all the results produced by this notebook 
# - this should be a path relative to your working directory
data_dir = 'project_data'

if not os.path.isdir(data_dir):
    os.makedirs(data_dir)

# %% [markdown]
# To get the dataset required for the poject run the cell below:
#
# Sequence:

# %%
! wget -nv -O $data_dir/sequence_data.qza 'https://polybox.ethz.ch/index.php/s/AsLORlvUbwgBWTq'
# Out:
# 2022-10-05 09:40:41 URL:https://polybox.ethz.ch/index.php/s/AsLORlvUbwgBWTq [13478/13478] -> "project_data/data.qza" [1]

# %% [markdown]
# Sample metadata:

# %%
! wget -nv -O $data_dir/sample_meta_data.tsv ' https://polybox.ethz.ch/index.php/s/QqbHeUIpIR0okB8'
